# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ac9e70aa-ec47-4732-be7e-9a1ecc5c41cc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ac9e70aa-ec47-4732-be7e-9a1ecc5c41cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('/content/raw_data_unmodified.csv')

# %%
df.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
df.isnull()
# Out:
#     movie_title  num_critic_for_reviews  duration  DIRECTOR_facebook_likes  \
# 0         False                   False     False                    False
# 1         False                   False      True                    False
# 2         False                   False     False                    False
# 3         False                   False      True                    False
# 4         False                   False     False                    False
# 5         False                   False     False                    False
# 6         False                   False      True                    False
# 7         False                   False     False                    False
# 8         False                   False     False                    False
# 9         False                   False     False                    False
# 10        False                   False     False                     True
# ...

# %%
df.isnull().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     3
# DIRECTOR_facebook_likes      2
# actor_3_facebook_likes       0
# ACTOR_1_facebook_likes       0
# gross                        0
# num_voted_users              1
# Cast_Total_facebook_likes    2
# facenumber_in_poster         5
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# ACTOR_2_facebook_likes       1
# imdb_score                   0
# title_year.1                 7
# dtype: int64

# %%
missing_data = df.isnull().sum()

df.fillna(0, inplace=True)

df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     0
# DIRECTOR_facebook_likes      0
# actor_3_facebook_likes       0
# ACTOR_1_facebook_likes       0
# gross                        0
# num_voted_users              0
# Cast_Total_facebook_likes    0
# facenumber_in_poster         0
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# ACTOR_2_facebook_likes       0
# imdb_score                   0
# title_year.1                 0
# dtype: int64

# %%
df.dtypes
# Out:
# movie_title                   object
# num_critic_for_reviews         int64
# duration                     float64
# DIRECTOR_facebook_likes       object
# actor_3_facebook_likes         int64
# ACTOR_1_facebook_likes         int64
# gross                          int64
# num_voted_users              float64
# Cast_Total_facebook_likes    float64
# facenumber_in_poster         float64
# num_user_for_reviews           int64
# budget                         int64
# title_year                     int64
# ACTOR_2_facebook_likes       float64
# imdb_score                   float64
# title_year.1                 float64
# dtype: object

# %%
print(df['DIRECTOR_facebook_likes'].unique())
# Out:
# ['10' '563' '20' '22000' '"475"' '23' '15' '282' 0 '395']

# %%
df['DIRECTOR_facebook_likes'] = df['DIRECTOR_facebook_likes'].str.replace('"', '', regex=False).str.strip()
df['DIRECTOR_facebook_likes'].fillna(0, inplace=True)
# Out:
# <ipython-input-27-149bdc843595>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['DIRECTOR_facebook_likes'].fillna(0, inplace=True)

# %%
print(df['DIRECTOR_facebook_likes'].unique())
# Out:
# ['10' '563' '20' '22000' '475' '23' '15' '282' 0 '395']

# %%
df['DIRECTOR_facebook_likes'] = df['DIRECTOR_facebook_likes'].astype(int)

# %%
duplicates = df.duplicated().sum()
duplicates
# Out:
# 0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   movie_title                14 non-null     object
#  1   num_critic_for_reviews     14 non-null     int64
#  2   duration                   14 non-null     float64
#  3   DIRECTOR_facebook_likes    14 non-null     int64
#  4   actor_3_facebook_likes     14 non-null     int64
#  5   ACTOR_1_facebook_likes     14 non-null     int64
#  6   gross                      14 non-null     int64
#  7   num_voted_users            14 non-null     float64
#  8   Cast_Total_facebook_likes  14 non-null     float64
#  9   facenumber_in_poster       14 non-null     float64
#  10  num_user_for_reviews       14 non-null     int64
#  11  budget                     14 non-null     int64
#  12  title_year                 14 non-null     int64
# ...
